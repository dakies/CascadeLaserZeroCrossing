# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook



X, Y = [], []
for line in open('kalman_c_orig.txt', 'r'):
  values = [float(s) for s in line.split()]
  Y.append(values[0])
plt.plot(Y, label='Original Signal')
maxy = np.max(Y)

X, Y = [], []
for line in open('kalman_filt.txt', 'r'):
  values = [float(s) for s in line.split()]
  Y.append(values[0])
plt.plot(Y, label='Filterd Signal')
    
X, Y = [], []
for line in open('kalman_c_hp.txt', 'r'):
  values = [float(s) for s in line.split()]
  Y.append(values[0])
plt.plot(0.012*np.array(Y), label='Zero detection')


plt.ion()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
